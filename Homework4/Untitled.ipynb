# %%
from __future__ import division
# %matplotlib notebook

A = 0.5
a = 0.5

#each genotype has a fitness
fAA = 1
fAa = 1
faa = 0.9

Al = [A]

for i in range(1000): # range is the number of generations
    sum = (A**2 * fAA) + (2*A*a * fAa) + (a**2 * faa)
    
    A1 = ((A**2 * fAA)/sum) + ((2*A*a * fAa)/sum)
    a1 = ((2*A*a * fAa)/sum) + ((a**2 * faa)/sum)
    A, a = A1, a1
    
    Al.append(A)

from matplotlib import pyplot as plt
plt.plot(Al)
print A1

#need to enforce a population size to incorporate drift
#BINOMIAL DISTRIBUTION WILL BE HELPFUL IN THIS
#Bionomia(n,p)
#There is going to be a problem, he wants us to figure out where.

#The population is going to change so how do we enforce a population size with random numbers?
    #Graph should not go above 1
# Out:
# <img src="data:image/png;base64,...">
# 0.791183294664
